# %% [markdown]
# # Template Matching

# %% [markdown]
# ### Full Image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full = cv2.imread('./DATA/sammy.jpg')
full = cv2.cvtColor(full, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(full)

# %% [markdown]
# ### Template Image
#
# A subset of the image. Note how its actually the exact image. Later on we'll discuss more advanced methods for general matching, such as facial recognition.

# %%
face = cv2.imread('../DATA/sammy_face.jpg')
face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(face)

# %% [markdown]
# # Template Matching Methods

# %% [markdown]
# **Quick Note on *eval()* function**

# %% [markdown]
# -------

# %%
sum([1,2,3])
# Out:
# 6

# %%
mystring = 'sum'

# %%
eval(mystring)
# Out:
# <function sum(iterable, /, start=0)>

# %%
myfunc = eval(mystring)

# %%
myfunc([1,2,3])
# Out:
# 6

# %% [markdown]
# -------

# %%
height, width, channels = face.shape

# %%
width
# Out:
# 486

# %%
height
# Out:
# 375

# %%
channels
# Out:
# 3

# %%
# The Full Image to Search
full = cv2.imread('./DATA/sammy.jpg')
full = cv2.cvtColor(full, cv2.COLOR_BGR2RGB)

# The Template to Match
face = cv2.imread('./DATA/sammy_face.jpg')
face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)

# All the 6 methods for comparison in a list
# Note how we are using strings, later on we'll use the eval() function to convert to function
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for m in methods:
    
    # Create a copy of the image
    full_copy = full.copy()
    
    # Get the actual function instead of the string
    method = eval(m)

    # Apply template Matching with the method
    res = cv2.matchTemplate(full_copy,face,method)  # gives output as a HEATMAP Image
    
    # Grab the Max and Min values, plus their locations
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)
    
    # Set up drawing of Rectangle
    
    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    # Notice the coloring on the last 2 left hand side images.
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc  # (x,y) coords 
    else:
        top_left = max_loc
        
    # Assign the Bottom Right of the rectangle
    bottom_right = (top_left[0] + width, top_left[1] + height)

    # Draw the Red Rectangle
    cv2.rectangle(full_copy,top_left, bottom_right, (255,0,0), 10)

    # Plot the Images
    plt.subplot(121)   # 121 means 1 row 2 columns and we choose the 1st row now to display the image
    plt.imshow(res)
    plt.title('HEATMAP (Result) of Template Matching')
    
    plt.subplot(122)   # 122 means 1 row 2 columns and we choose the 2nd row now to display the image
    plt.imshow(full_copy)
    plt.title('Detected Point')
    
    plt.suptitle(m)
    
    plt.show()
    print('\n')
    print('\n')
